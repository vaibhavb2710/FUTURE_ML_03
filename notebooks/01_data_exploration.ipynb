# %%
import pandas as pd

df = pd.read_csv("data/telco_churn.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("data/telco_churn.csv")
#       4 df.head()
#
# File c:\Users\vaibh\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py:31
#      28         _missing_dependencies.append(f"{_dependency}: {_e}")
#      30 if _missing_dependencies:  # pragma: no cover
# ---> 31     raise ImportError(
#      32         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      33     )
#      34 del _hard_dependencies, _dependency, _missing_dependencies
#      36 try:
#      37     # numpy compat
#
# ImportError: Unable to import required dependencies:
# numpy: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
# ...
